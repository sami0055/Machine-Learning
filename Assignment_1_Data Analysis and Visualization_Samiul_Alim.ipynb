# %% [markdown]
# # I
# 🦊 `Notebook by` [Md.Samiul Alim](https://github.com/sami0055)
#
# 😋  `Machine Learning Source Codes` [GitHub](https://github.com/sami0055/Machine-Learning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('Life_Expectancy_Data.csv')
df.head(5)
# Out:
#    Country          Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Turkiye     Middle East  2015           11.1               13.0
# 1    Spain  European Union  2015            2.7                3.3
# 2    India            Asia  2007           51.5               67.9
# 3   Guyana   South America  2006           32.8               40.5
# 4   Israel     Middle East  2012            3.4                4.3
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0         105.8240                 1.32           97       65  27.8  ...
# 1          57.9025                10.35           97       94  26.0  ...
# 2         201.0765                 1.57           60       35  21.2  ...
# 3         222.1965                 5.68           93       74  25.3  ...
# 4          57.9510                 2.89           97       89  27.0  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Year  Infant_deaths  Under_five_deaths  Adult_mortality  \
# count  2864.000000    2864.000000        2864.000000      2864.000000
# mean   2007.500000      30.363792          42.938268       192.251775
# std       4.610577      27.538117          44.569974       114.910281
# min    2000.000000       1.800000           2.300000        49.384000
# 25%    2003.750000       8.100000           9.675000       106.910250
# 50%    2007.500000      19.600000          23.100000       163.841500
# 75%    2011.250000      47.350000          66.000000       246.791375
# max    2015.000000     138.100000         224.900000       719.360500
#
#        Alcohol_consumption  Hepatitis_B      Measles          BMI  \
# count          2864.000000  2864.000000  2864.000000  2864.000000
# mean              4.820882    84.292598    77.344972    25.032926
# std               3.981949    15.995511    18.659693     2.193905
# min               0.000000    12.000000    10.000000    19.800000
# ...

# %% [markdown]
# # Which regions have more populations?

# %%
#Numerical Analysis
grouped=df.groupby("Region")
agg=grouped.agg({'Population_mln':['mean']})
agg
# Out:
#                               Population_mln
#                                         mean
# Region
# Africa                             18.438395
# Asia                              136.131782
# Central America and Caribbean       4.052237
# European Union                     16.210046
# Middle East                        19.360000
# North America                     148.473958
# Oceania                             3.230568
# Rest of Europe                     20.065833
# South America                      31.785260

# %%
sns.barplot(data=df,y='Region',x='Population_mln')
plt.xlabel("Population in Million")
plt.ylabel("Regions")
plt.title("Regions V/S Populations in Million")
plt.yticks(rotation=45)
plt.show()

# %% [markdown]
# ### Here it is clear that the highest population in North America, the second highest in Asia, and the region with the lowest population is Oceania.

# %% [markdown]
# ## What is the average  infant deaths across different region?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %%
grouped=df.groupby('Region')

# %%
agg=grouped.agg({'Infant_deaths':['mean']})
print(agg)
# Out:
#                               Infant_deaths
#                                        mean
# Region
# Africa                            60.604044
# Asia                              32.536111
# Central America and Caribbean     20.965461
# European Union                     4.872222
# Middle East                       16.639286
# North America                      9.925000
# Oceania                           26.305114
# Rest of Europe                     9.627917
# South America                     19.953646

# %%
sns.barplot(data=df,x=df['Infant_deaths'],y=df['Region'])
plt.xlabel("Infant Deaths")
plt.ylabel("Region")

plt.grid()
plt.show()

# %% [markdown]
# 'From this graph, we can conclude that the highest infant mortality occurs in Aferica and the lowest in the European Union's countries.'

# %% [markdown]
# ## What is the average under_five deaths across different region?

# %%
agg=grouped.agg({'Under_five_deaths':['mean']})
print(agg)
# Out:
#                               Under_five_deaths
#                                            mean
# Region
# Africa                                94.025000
# Asia                                  40.965278
# Central America and Caribbean         25.932237
# European Union                         5.858333
# Middle East                           20.457143
# North America                         11.647917
# Oceania                               32.493750
# Rest of Europe                        11.179583
# South America                         23.938021

# %%
plt.figure(figsize=(8,8))
plt.xticks(rotation=45)
sns.barplot(data=df,x=df['Region'],y=df['Under_five_deaths'])
plt.xlabel("Region")
plt.ylabel("Average Under Five Deaths")
plt.grid()
plt.tight_layout()

# %% [markdown]
# From this graph, we can conclude that Aferica has more mortality, like infant mortality, and the countries with the lowest under-five deaths are the European Union's countries.

# %% [markdown]
# # How has adult mortality changed over the years?

# %%
grouped=df.groupby('Year')
agg=grouped.agg({'Adult_mortality':['mean']})
agg
# Out:
#      Adult_mortality
#                 mean
# Year
# 2000      217.693450
# 2001      216.753321
# 2002      215.759645
# 2003      211.633478
# 2004      207.448028
# 2005      203.649749
# 2006      199.528285
# 2007      195.409966
# 2008      190.803089
# 2009      186.124000
# 2010      181.587232
# 2011      177.214165
# 2012      172.649818
# 2013      169.575905
# 2014      166.530704
# 2015      163.667570

# %%
sns.lineplot(data=df,x='Year',y='Adult_mortality',color='r')
plt.title("Line plot of Adult Mortality over the years")
plt.xlabel("Date")
plt.ylabel("Adult Mortality")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From this graph, we can say that adult mortality has decreased over the years.

# %% [markdown]
# # What is the average alcohol consumption in developed and developing countries?

# %%
grouped=df.groupby('Economy_status_Developed')
for name,group in grouped:
    print(name)
    print(group)
# Out:
# 0
#                  Country                         Region  Year  Infant_deaths  \
# 0                Turkiye                    Middle East  2015           11.1
# 2                  India                           Asia  2007           51.5
# 3                 Guyana                  South America  2006           32.8
# 5             Costa Rica  Central America and Caribbean  2006            9.8
# 6     Russian Federation                 Rest of Europe  2015            6.6
# ...                  ...                            ...   ...            ...
# 2857             Belarus                 Rest of Europe  2000            9.9
# 2858  Iran, Islamic Rep.                    Middle East  2007           19.7
# 2859               Niger                         Africa  2000           97.0
# 2860            Mongolia                           Asia  2009           23.9
# 2861           Sri Lanka                           Asia  2004           17.7
#
# ...

# %%
agg=grouped.agg({'Alcohol_consumption':['mean']})
agg
# Out:
#                          Alcohol_consumption
#                                         mean
# Economy_status_Developed
# 0                                   3.458532
# 1                                  10.049358

# %%
sns.barplot(data=df,x='Economy_status_Developed',y='Alcohol_consumption')
plt.title("Average Alcohol Consumers in Developed and Developing Countries")
plt.xlabel("Economy Status Developing=0 and Developed=1")
plt.ylabel("Average Alcohol Consumption")
# Out:
# Text(0, 0.5, 'Average Alcohol Consumption')

# %% [markdown]
# From this graph, we can say that people in developed countries are more alcohol consumers than in developing countries.

# %% [markdown]
# # Is there a correlation between Hepatitis B vaccination coverage and life expectancy?

# %%
df.corr()
# Out:
# C:\Users\SAMI\AppData\Local\Temp\ipykernel_12456\1886530979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                      Year  Infant_deaths  Under_five_deaths  \
# Year                         1.000000e+00      -0.172402          -0.176393
# Infant_deaths               -1.724017e-01       1.000000           0.985651
# Under_five_deaths           -1.763926e-01       0.985651           1.000000
# Adult_mortality             -1.586596e-01       0.794661           0.802361
# Alcohol_consumption         -6.105222e-04      -0.454526          -0.409367
# Hepatitis_B                  1.768241e-01      -0.512562          -0.507427
# Measles                      8.594472e-02      -0.526282          -0.512972
# ...

# %%
sns.scatterplot(data=df,x=df['Hepatitis_B'],y=df['Life_expectancy'])
# Out:
# <Axes: xlabel='Hepatitis_B', ylabel='Life_expectancy'>

# %%
sns.lineplot(data=df,x=df['Hepatitis_B'],y=df['Life_expectancy'])
# Out:
# <Axes: xlabel='Hepatitis_B', ylabel='Life_expectancy'>

# %% [markdown]
# From these two graphs, we can conclude that there is no good relationship between Hapatitis_B Coveraged Country and Life Expectancy.

# %% [markdown]
# # Is there any relationship between alcohol consumption and adult mortality?

# %%
sns.scatterplot(data=df,x=df['Alcohol_consumption'],y='Adult_mortality')
# Out:
# <Axes: xlabel='Alcohol_consumption', ylabel='Adult_mortality'>

# %%
sns.lineplot(data=df,x=df['Alcohol_consumption'],y='Adult_mortality')
# Out:
# <Axes: xlabel='Alcohol_consumption', ylabel='Adult_mortality'>

# %% [markdown]
# ### From these two graphs, we can say that there is no good relationship between alcohol consumption and adult mortality, as the data graphs vary.

# %% [markdown]
# # Is there any relationship between Economic Status and schooling?

# %%
grouped=df.groupby('Economy_status_Developed')
agg=grouped.agg({'Schooling':['mean']})
print(agg)
# Out:
#                           Schooling
#                                mean
# Economy_status_Developed
# 0                          6.661840
# 1                         11.355912

# %%
sns.barplot(data=df,x='Economy_status_Developed',y='Schooling')
plt.title("Economy Status VS Schooling")
plt.xlabel("Economy_Status_Developed=1 and Economy_Status_Developing=0")
plt.ylabel("Schooling")
plt.show()

# %%
sns.lineplot(data=df,x='Economy_status_Developed',y='Schooling')
plt.title("Economy Status VS Schooling")
plt.xlabel("Economy_Status_Developed=1 and Economy_Status_Developing=0")
plt.ylabel("Schooling")
plt.show()

# %% [markdown]
# Based on these two graphs, we can conclude that developed countries have more schooling than developing countries.

# %% [markdown]
# # What is the significant differences in BMI between different regions

# %%
grouped=df.groupby('Region')
agg=grouped.agg({'BMI':['mean']})
print(agg)
# Out:
#                                      BMI
#                                     mean
# Region
# Africa                         23.249265
# Asia                           23.412269
# Central America and Caribbean  26.274671
# European Union                 26.021528
# Middle East                    26.927679
# North America                  27.429167
# Oceania                        27.203977
# Rest of Europe                 25.991250
# South America                  26.071875

# %%
sns.barplot(data=df,y='Region',x='BMI')
plt.grid()
plt.title("Region V/S BMI")
plt.yticks(rotation=45)
plt.ylabel("Region")
plt.xlabel("BMI")
plt.show()

# %% [markdown]
# From this graph, we can say that there is not that much difference between region and BMI. However, the highest BMI is in North America and the lowest in Africa.

# %% [markdown]
# # What is the relationship between BMI and life expectancy? Is BMI affecting life expectancy?

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=df,x=df['BMI'],y=df['Life_expectancy'])
plt.title("Life Expectancy V/S BMI")
plt.ylabel("Life Expectancy")
plt.xlabel("BMI")
plt.grid()

# %% [markdown]
# From this graph, we can conclude that people with a BMI between 25 and 28 have a longer life expectancy.

# %% [markdown]
# # Is there any relationship between polio vaccine coverage and life expectancy?

# %%
sns.scatterplot(data=df,x='Polio',y='Life_expectancy')
plt.xlabel("Polio")
plt.ylabel("Life Expectancy")
plt.title("Polio V/S Life Expectancy")
# Out:
# Text(0.5, 1.0, 'Polio V/S Life Expectancy')

# %%
sns.lineplot(data=df,x='Polio',y='Life_expectancy',color='g')
sns.regplot(x='Polio', y='Life_expectancy', data=df, ci=None, line_kws={'color': 'red'})
plt.xlabel("Polio")
plt.ylabel("Life Expectancy")
plt.title("Polio V/S Life Expectancy")
plt.show()

# %% [markdown]
# From these two graphs, we can say that those countries with more polio vaccine coverage have a longer life expectancy.

# %% [markdown]
# # Which People are more affected by HIV Incidents?According to the dataset?

# %%
df.corr()
# Out:
# C:\Users\SAMI\AppData\Local\Temp\ipykernel_12456\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                      Year  Infant_deaths  Under_five_deaths  \
# Year                         1.000000e+00      -0.172402          -0.176393
# Infant_deaths               -1.724017e-01       1.000000           0.985651
# Under_five_deaths           -1.763926e-01       0.985651           1.000000
# Adult_mortality             -1.586596e-01       0.794661           0.802361
# Alcohol_consumption         -6.105222e-04      -0.454526          -0.409367
# Hepatitis_B                  1.768241e-01      -0.512562          -0.507427
# Measles                      8.594472e-02      -0.526282          -0.512972
# ...

# %% [markdown]
# ## From this correlation table, we can say that adult people are the prime victims of HIV

# %%
sns.scatterplot(data=df,x='Incidents_HIV',y='Adult_mortality')
plt.xlabel("HIV Incidents")
plt.ylabel("Adult_mortality")
plt.title("HIV Incidents V/S Adult_mortality")
# Out:
# Text(0.5, 1.0, 'HIV Incidents V/S Adult_mortality')

# %%
sns.lineplot(data=df,x='Incidents_HIV',y='Adult_mortality')
sns.regplot(x='Incidents_HIV',y='Adult_mortality', data=df, ci=None, line_kws={'color': 'red'})
plt.xlabel("HIV Incidents")
plt.ylabel("Adult_mortality")
plt.title("HIV Incidents V/S Adult_mortality")
# Out:
# Text(0.5, 1.0, 'HIV Incidents V/S Adult_mortality')

# %% [markdown]
# ### From these two graphs, we can say that when HIV incidents increase, at the same time, adult mortality also increases.

# %% [markdown]
# # Which regions are more affected by HIV incidents?

# %%
grouped=df.groupby('Region')
agg=grouped.agg({'Incidents_HIV':['mean']})
agg
# Out:
#                               Incidents_HIV
#                                        mean
# Region
# Africa                             2.702132
# Asia                               0.139884
# Central America and Caribbean      0.419375
# European Union                     0.073912
# Middle East                        0.089063
# North America                      0.127917
# Oceania                            0.155284
# Rest of Europe                     0.107292
# South America                      0.298333

# %%
sns.barplot(data=df,y='Region',x='Incidents_HIV')
plt.xlabel("Incidents of HIV")
plt.ylabel("Region")
plt.title("Region V/S HIV Incidents")
plt.yticks(rotation=45)
plt.show()

# %%
grouped=df.groupby('Region')
agg=grouped.agg({'Incidents_HIV':['mean']})
arr=np.array([])
regions=np.array([])
for i,value in agg.iterrows():
    regions=np.append(regions,i)
    arr=np.append(arr,value)


fig, ax = plt.subplots(figsize=(5, 5))  # Adjust figure size as needed
wedges, texts, autotexts = ax.pie(arr, autopct='%1.1f%%', startangle=90, pctdistance=0.8)

# Adjust label and autopct distances to avoid overlap
for text, autotext in zip(texts, autotexts):
    text.set_size('smaller')
    autotext.set_size('smaller')

# Make the legend outside the pie chart
ax.legend(wedges, regions, title="Regions",  loc="center left", bbox_to_anchor=(1, 0.5),bbox_transform=plt.gcf().transFigure)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')

plt.show()

# %% [markdown]
# ### From this two graph, we saw that the Aferica region is the most affected by HIV incidents, and the second highest is Central America and Caribbean. The lowest one is the Europian Union.

# %% [markdown]
# # How infant deaths and under-five deaths vary across the different years. Is it increasing or decreasing?

# %%
#Numerical Analysis of infant deaths in different year
grouped=df.groupby('Year')
agg=grouped.agg({'Infant_deaths':['mean']})
print(agg)
# Out:
#      Infant_deaths
#               mean
# Year
# 2000     38.997207
# 2001     37.632402
# 2002     36.281006
# 2003     34.984916
# 2004     33.776536
# 2005     32.499441
# 2006     31.319553
# 2007     30.262570
# 2008     29.333520
# 2009     28.305028
# 2010     27.571508
# 2011     26.454749
# 2012     25.677095
# 2013     24.925140
# 2014     24.241341
# 2015     23.558659

# %%
#Numerical Analysis of  under five year deaths in different year
grouped=df.groupby('Year')
agg=grouped.agg({'Under_five_deaths':['mean']})
print(agg)
# Out:
#      Under_five_deaths
#                   mean
# Year
# 2000         57.015642
# 2001         54.858101
# 2002         52.692737
# 2003         50.598883
# 2004         48.709497
# 2005         46.618436
# 2006         44.696648
# 2007         42.880447
# 2008         41.317877
# 2009         39.514525
# 2010         38.490503
# 2011         36.333520
# 2012         35.040782
# 2013         33.821788
# 2014         32.742458
# 2015         31.680447

# %%
sns.barplot(data=df,x='Year',y='Infant_deaths')
plt.xlabel("YEAR")
plt.ylabel("Infant Deaths")
plt.title("Infant Deaths V/S Year")
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_palette("dark")
sns.barplot(data=df,x='Year',y='Under_five_deaths')
plt.xlabel("YEAR")
plt.ylabel("Under_five_deaths")
plt.title("Under Five Deaths V/S Year")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### From these two graphs, we can conclude that day by day, the deaths of infancy and underfive-year-olds are decreasing.

# %% [markdown]
# # Which regions have more GDP per capita?

# %%
#Numerical Analysis
grouped=df.groupby('Region')
agg=grouped.agg({'GDP_per_capita':['mean']})
print(agg)
# Out:
#                               GDP_per_capita
#                                         mean
# Region
# Africa                           2314.009804
# Asia                             6560.958333
# Central America and Caribbean    8387.812500
# European Union                  28140.368056
# Middle East                     18957.281250
# North America                   33783.854167
# Oceania                         10146.971591
# Rest of Europe                  19090.150000
# South America                    7232.031250

# %%
sns.barplot(data=df,y='Region',x='GDP_per_capita',orient='h')
plt.title("Regions V/S GDP Per Capita")
plt.xlabel("GDP Per Capita")
plt.ylabel("Region")
plt.show()

# %% [markdown]
# ### So here, the highest GDP per capita is in North America and the lowest GDP per capita is in Africa.

# %% [markdown]
# # What trends can be observed in thinness rates among adolescents over time?

# %%
sns.histplot(data=df,x='Thinness_ten_nineteen_years')
plt.xlabel("Thnness Ten Ninteen Years")
plt.ylabel("Count")
plt.title("Hisplot of Thiness ten to ninteen years")
plt.grid()
plt.show()

# %% [markdown]
# ### Thinness between zero and four is the highest.
